# %%
import pandas as pd
import geopandas as gpd

# %%
students = pd.read_csv("./data/students.csv")
schools = pd.read_excel("./data/finalized_schools.xlsx")

schools = schools[schools["Status"].isna()]
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_27072\3526968350.py:1: DtypeWarning: Columns (0: Grade, 1: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Male householder, no spouse present: Under 3 years/Value, 2: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Male householder, no spouse present: Under 3 years/Margin of error, 3: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Male householder, no spouse present: Under 3 years/Percentage, 4: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Male householder, no spouse present: 3 and 4 years/Value, 5: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Male householder, no spouse present: 3 and 4 years/Margin of error, 6: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Male householder, no spouse present: 3 and 4 years/Percentage, 7: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Male householder, no spouse present: 5 years/Value, 8: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Male householder, no spouse present: 5 years/Margin of error, 9: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Male householder, no spouse present: 5 years/Percentage, 10: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Male householder, no spouse present: 12 to 17 years/Margin of error, 11: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Male householder, no spouse present: 12 to 17 years/Percentage, 12: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Female householder, no spouse present/Value, 13: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Female householder, no spouse present/Margin of error, 14: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Female householder, no spouse present/Percentage, 15: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Female householder, no spouse present: Under 3 years/Value, 16: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Female householder, no spouse present: Under 3 years/Margin of error, 17: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Female householder, no spouse present: Under 3 years/Percentage, 18: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Female householder, no spouse present: 3 and 4 years/Value, 19: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Female householder, no spouse present: 3 and 4 years/Percentage, 20: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Female householder, no spouse present: 5 years/Margin of error, 21: ACS Families/Own Children Under 18 Years by Family Type and Age/In other families: Female householder, no spouse present: 6 to 11 years/Percentage, 22: Elementary School District Grade Low, 23: HMDA/CRA collection year) have mixed types. Specify dtype option on import or set low_memory=False.
#   students = pd.read_csv("./data/students.csv")

# %%
students_in_schools_with_status = students[students["School Code"].isin(schools["School Code"])]
students_in_schools_with_status.head()
# Out:
#      School Code Grade                                            Address  \
# 0  THAYER CAMPUS    10            58 Second ST Apt B Framingham, MA 01702
# 1  THAYER CAMPUS    11                 7 Barbieri RD Framingham, MA 01702
# 2  THAYER CAMPUS    12                  120 Grant ST Framingham, MA 01702
# 3  THAYER CAMPUS    11                   157 Grant ST Framingham MA 01702
# 4  THAYER CAMPUS    10  364 Irving Street Apt Block A - apt 105 Framin...
#
#          TOWN  TOWN_ID TYPE     COUNTY  FIPS_STCO  FOURCOLOR  POP1960  ...  \
# 0  FRAMINGHAM    100.0    C  MIDDLESEX    25017.0        4.0  44526.0  ...
# 1  FRAMINGHAM    100.0    C  MIDDLESEX    25017.0        4.0  44526.0  ...
# 2  FRAMINGHAM    100.0    C  MIDDLESEX    25017.0        4.0  44526.0  ...
# 3  FRAMINGHAM    100.0    C  MIDDLESEX    25017.0        4.0  44526.0  ...
# 4  FRAMINGHAM    100.0    C  MIDDLESEX    25017.0        4.0  44526.0  ...
#
#    Tract median family income as a percentage of the MSA/MD median family income  \
# 0                                              35.50
# 1                                              74.80
# 2                                              71.91
# 3                                              71.91
# 4                                              38.61
#
#    FFIEC Estimated MSA/MD median family income  Income indicator  \
# 0                                     146600.0               Low
# 1                                     146600.0          Moderate
# 2                                     146600.0          Moderate
# 3                                     146600.0          Moderate
# 4                                     146600.0               Low
#
#    CRA poverty criteria?  CRA unemployment criteria?  \
# 0                     No                          No
# 1                     No                          No
# 2                     No                          No
# 3                     No                          No
# 4                     No                          No
#
#    CRA distressed criteria?  CRA remote rural (low density) criteria?  \
# 0                        No                                        No
# 1                        No                                        No
# 2                        No                                        No
# 3                        No                                        No
# 4                        No                                        No
#
#    Previous year CRA distressed criteria?  \
# 0                                      No
# 1                                      No
# 2                                      No
# 3                                      No
# 4                                      No
#
#    Previous year CRA underserved criterion?  \
# 0                                        No
# 1                                        No
# 2                                        No
# 3                                        No
# 4                                        No
#
#    Meets at least one of current or previous year's CRA distressed/underserved tract criteria?
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
# [5 rows x 741 columns]

# %%
with open("./data/finalized_students.csv", "w") as f:
    students_in_schools_with_status.to_csv(f, index=False)

# %%
df = students_in_schools_with_status.copy(deep=True)

del df['geometry']
df = df[(df['Geocodio Latitude'] != 0) & (df['Geocodio Longitude'] != 0)]

geometry = gpd.points_from_xy(df["Geocodio Longitude"], df["Geocodio Latitude"])
gdf = gpd.GeoDataFrame(df, geometry=geometry, crs="EPSG:4269")
gdf
# Out:
#         School Code Grade                                            Address  \
# 0     THAYER CAMPUS    10            58 Second ST Apt B Framingham, MA 01702
# 1     THAYER CAMPUS    11                 7 Barbieri RD Framingham, MA 01702
# 2     THAYER CAMPUS    12                  120 Grant ST Framingham, MA 01702
# 3     THAYER CAMPUS    11                   157 Grant ST Framingham MA 01702
# 4     THAYER CAMPUS    10  364 Irving Street Apt Block A - apt 105 Framin...
# ...             ...   ...                                                ...
# 8855            WAL     6                23 Juniper lane Framingham MA 01701
# 8856            WAL     8                23 Juniper lane Framingham MA 01701
# 8857            WAL     7            12 Harmony LN Apt B Framingham MA 01702
# 8858            WAL     7         50 Dinsmore AV Apt 404 Framingham MA 01702
# 8859            WAL     6                  577 Winter St Framingham MA 01702
#
#             TOWN  TOWN_ID TYPE     COUNTY  FIPS_STCO  FOURCOLOR  POP1960  ...  \
# 0     FRAMINGHAM    100.0    C  MIDDLESEX    25017.0        4.0  44526.0  ...
# 1     FRAMINGHAM    100.0    C  MIDDLESEX    25017.0        4.0  44526.0  ...
# 2     FRAMINGHAM    100.0    C  MIDDLESEX    25017.0        4.0  44526.0  ...
# 3     FRAMINGHAM    100.0    C  MIDDLESEX    25017.0        4.0  44526.0  ...
# 4     FRAMINGHAM    100.0    C  MIDDLESEX    25017.0        4.0  44526.0  ...
# ...          ...      ...  ...        ...        ...        ...      ...  ...
# 8855  FRAMINGHAM    100.0    C  MIDDLESEX    25017.0        4.0  44526.0  ...
# 8856  FRAMINGHAM    100.0    C  MIDDLESEX    25017.0        4.0  44526.0  ...
# 8857  FRAMINGHAM    100.0    C  MIDDLESEX    25017.0        4.0  44526.0  ...
# 8858  FRAMINGHAM    100.0    C  MIDDLESEX    25017.0        4.0  44526.0  ...
# 8859  FRAMINGHAM    100.0    C  MIDDLESEX    25017.0        4.0  44526.0  ...
#
#       FFIEC Estimated MSA/MD median family income  Income indicator  \
# 0                                        146600.0               Low
# 1                                        146600.0          Moderate
# 2                                        146600.0          Moderate
# 3                                        146600.0          Moderate
# 4                                        146600.0               Low
# ...                                           ...               ...
# 8855                                     146600.0            Middle
# 8856                                     146600.0            Middle
# 8857                                     146600.0          Moderate
# 8858                                     146600.0          Moderate
# 8859                                     146600.0            Middle
#
#       CRA poverty criteria?  CRA unemployment criteria?  \
# 0                        No                          No
# 1                        No                          No
# 2                        No                          No
# 3                        No                          No
# 4                        No                          No
# ...                     ...                         ...
# 8855                     No                          No
# 8856                     No                          No
# 8857                     No                          No
# 8858                     No                          No
# 8859                     No                          No
#
#       CRA distressed criteria?  CRA remote rural (low density) criteria?  \
# 0                           No                                        No
# 1                           No                                        No
# 2                           No                                        No
# 3                           No                                        No
# 4                           No                                        No
# ...                        ...                                       ...
# 8855                        No                                        No
# 8856                        No                                        No
# 8857                        No                                        No
# 8858                        No                                        No
# 8859                        No                                        No
#
#       Previous year CRA distressed criteria?  \
# 0                                         No
# 1                                         No
# 2                                         No
# 3                                         No
# 4                                         No
# ...                                      ...
# 8855                                      No
# 8856                                      No
# 8857                                      No
# 8858                                      No
# 8859                                      No
#
#       Previous year CRA underserved criterion?  \
# 0                                           No
# 1                                           No
# 2                                           No
# 3                                           No
# 4                                           No
# ...                                        ...
# 8855                                        No
# 8856                                        No
# 8857                                        No
# 8858                                        No
# 8859                                        No
#
#       Meets at least one of current or previous year's CRA distressed/underserved tract criteria?  \
# 0                                                    No
# 1                                                    No
# 2                                                    No
# 3                                                    No
# 4                                                    No
# ...                                                 ...
# 8855                                                 No
# 8856                                                 No
# 8857                                                 No
# 8858                                                 No
# 8859                                                 No
#
#                         geometry
# 0      POINT (-71.39995 42.2763)
# 1     POINT (-71.43026 42.26333)
# 2     POINT (-71.41058 42.28235)
# 3     POINT (-71.40923 42.28333)
# 4     POINT (-71.40645 42.26991)
# ...                          ...
# 8855  POINT (-71.44164 42.33312)
# 8856  POINT (-71.44164 42.33312)
# 8857  POINT (-71.43951 42.26806)
# 8858  POINT (-71.40167 42.29601)
# 8859  POINT (-71.44067 42.28282)
#
# [8372 rows x 741 columns]

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
school_districts = gpd.read_file("../data/census/school_district/tl_2025_25_unsd.shp")
framingham_district = school_districts[school_districts["NAME"].str.startswith("Framingham")]

framingham_district.plot()
# Out:
# <Axes: >

# %%
base = framingham_district.plot(color='white', edgecolor='black')
gdf.plot(ax=base, marker='o', color='red', markersize=5)
# Out:
# <Axes: >

# %%
within = [geo.within(framingham_district.geometry.iloc[0]) for geo in gdf.geometry]
within_students = gdf[within]

base = framingham_district.plot(color='white', edgecolor='black')
within_students.plot(ax=base, marker='o', color='red', markersize=5)
# Out:
# <Axes: >

# %%
percentage_within = len(within_students) / len(gdf)
print(f"{percentage_within:.2%} of students are within the Framingham school district.")
# Out:
# 99.08% of students are within the Framingham school district.

# %%
# geocode all the schools

school_geometry = gpd.points_from_xy(schools["Geocodio Longitude"], schools["Geocodio Latitude"])
school_gdf = gpd.GeoDataFrame(schools, geometry=school_geometry, crs="EPSG:4269")

base = framingham_district.plot(color='white', edgecolor='black')
school_gdf.plot(ax=base, marker='o', color='black', markersize=5)
# Out:
# <Axes: >

# %%
# Calculate average distance to school for students within the district
# use the school code to find the corresponding school for each student, then calculate the distance

within_students = within_students.assign(
    school_geometry=within_students["School Code"].map(school_gdf.set_index("School Code").geometry)
)

# %%
CRS = "EPSG:26986"  # Massachusetts State Plane Mainland
school_gdf = school_gdf.to_crs(CRS)

def get_distance_to_school(student_row):
    school_code = student_row["School Code"]
    school_row = school_gdf[school_gdf["School Code"] == school_code]
    if len(school_row) == 0:
        return None
    school_geometry = school_row.geometry.iloc[0]
    return student_row.geometry.distance(school_geometry)

in_meters_crs = within_students.to_crs("EPSG:26986")
in_meters_crs = in_meters_crs.assign(
    distance_to_school=in_meters_crs.apply(get_distance_to_school, axis=1)
)

# %%
average_distance = in_meters_crs["distance_to_school"].mean()
print(f"Average distance to school for students within the district: {average_distance:.2f} meters")
# Out:
# Average distance to school for students within the district: 3495.17 meters

# %%
# get block groups within school district and their median income

income = pd.read_csv("./data/income.csv")
income.rename(columns={"Geo__geoid_": "GEOID", "SE_A14006_001": "income"}, inplace=True)
block_groups = gpd.read_file("../data/census/block_groups/tl_2025_25_bg.shp")

block_groups["GEOID"] = block_groups["GEOID"].astype(str)
income["GEOID"] = income["GEOID"].astype(str)

block_groups = block_groups.merge(income, left_on="GEOID", right_on="GEOID")
# combine based on GEOID

only_bg_inside = [geo.within(framingham_district.geometry.iloc[0]) for geo in block_groups.geometry]
within_block_groups = block_groups[only_bg_inside]

# %%
# plot next to each other
import matplotlib.pyplot as plt

# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
fig_d, ax_d = plt.subplots()

# %%
# Map of students based on distnace to school

framingham_district.to_crs(CRS).plot(ax=ax_d, color='white', edgecolor='black')
in_meters_crs.plot(ax=ax_d, column='distance_to_school', cmap='Reds', marker='o', markersize=5, legend=True, legend_kwds={'label': "Distance to School (meters)"})
school_gdf.to_crs(CRS).plot(ax=ax_d, marker='x', color='black', markersize=50)

ax_d.set_title("Students in Framingham by Distance to School")
ax_d.set_axis_off()

for x, y, label in zip(school_gdf.geometry.x, school_gdf.geometry.y, school_gdf["School Code"]):
    ax_d.annotate(label, xy=(x, y), xytext=(3, 3), textcoords="offset points")

ax_d.plot()
# Out:
# []

# %%
fig_d.savefig("students_distance_to_school.png", dpi=300, bbox_inches="tight",)

# %%
within_block_groups.head()
# Out:
#    STATEFP COUNTYFP TRACTCE BLKGRPCE         GEOID                GEOIDFQ  \
# 63      25      017  383102        2  250173831022  1500000US250173831022
# 64      25      017  383101        2  250173831012  1500000US250173831012
# 65      25      017  383200        2  250173832002  1500000US250173832002
# 66      25      017  383200        3  250173832003  1500000US250173832003
# 67      25      017  383200        4  250173832004  1500000US250173832004
#
#          NAMELSAD  MTFCC FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 63  Block Group 2  G5030        S   342612       0  +42.2763952  -071.3994365
# 64  Block Group 2  G5030        S  1181213    8102  +42.2628644  -071.4121402
# 65  Block Group 2  G5030        S   508307  302355  +42.2661673  -071.4264950
# 66  Block Group 3  G5030        S   347016     655  +42.2726091  -071.4228537
# 67  Block Group 4  G5030        S   999451       0  +42.2706171  -071.4350505
#
#                                              geometry  \
# 63  POLYGON ((-71.40256 42.27527, -71.40165 42.276...
# 64  POLYGON ((-71.41845 42.27315, -71.4183 42.2736...
# 65  POLYGON ((-71.43139 42.26736, -71.43136 42.267...
# 66  POLYGON ((-71.42946 42.27201, -71.42911 42.272...
# 67  POLYGON ((-71.44462 42.27059, -71.44377 42.271...
#
#                                              Geo_NAME  \
# 63  Block Group 2, Census Tract 3831.02, Middlesex...
# 64  Block Group 2, Census Tract 3831.01, Middlesex...
# 65  Block Group 2, Census Tract 3832, Middlesex Co...
# 66  Block Group 3, Census Tract 3832, Middlesex Co...
# 67  Block Group 4, Census Tract 3832, Middlesex Co...
#
#                                             Geo_qname  Geo_AREALAND  \
# 63  Block Group 2, Census Tract 3831.02, Middlesex...        342612
# 64  Block Group 2, Census Tract 3831.01, Middlesex...       1181213
# 65  Block Group 2, Census Tract 3832, Middlesex Co...        508307
# 66  Block Group 3, Census Tract 3832, Middlesex Co...        347016
# 67  Block Group 4, Census Tract 3832, Middlesex Co...        999451
#
#     Geo_AREAWATER    income
# 63              0   48191.0
# 64           8102  100893.0
# 65         302355   92336.0
# 66            655   74688.0
# 67              0  152303.0

# %%
# plot median income by block group

fig_m, ax_m = plt.subplots()

framingham_district.to_crs(CRS).plot(ax=ax_m, color='white', edgecolor='black')
within_block_groups.to_crs(CRS).plot(ax=ax_m, column='income', cmap='Blues', legend=True, legend_kwds={'label': "Median Income ($)"})
ax_m.set_title("Median Income by Block Group in Framingham")

ax_m.set_axis_off()
ax_m.plot()
# Out:
# []

# %%
fig_m.savefig("median_income_by_block_group.png", dpi=300, bbox_inches="tight",)
